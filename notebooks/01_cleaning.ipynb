# %%
import pandas as pd

# %%
df_pokemon = pd.read_csv('../data/pokemon.csv')

# %%
df_pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df_columns = ['name', 'type1', 'type2', 'hp', 'attack', 
           'defense', 'sp_attack', 'sp_defense', 'speed', 
           'generation', 'is_legendary']

# %%
df_pokemon = df[df_columns]

# %%
df_pokemon.head()
# Out:
#          name  type1   type2  hp  attack  defense  sp_attack  sp_defense  \
# 0   Bulbasaur  grass  poison  45      49       49         65          65
# 1     Ivysaur  grass  poison  60      62       63         80          80
# 2    Venusaur  grass  poison  80     100      123        122         120
# 3  Charmander   fire     NaN  39      52       43         60          50
# 4  Charmeleon   fire     NaN  58      64       58         80          65
#
#    speed  generation  is_legendary
# 0     45           1             0
# 1     60           1             0
# 2     80           1             0
# 3     65           1             0
# 4     80           1             0

# %%
# Detectando se tem valores nulos
df_pokemon.isna().sum()
# Out:
# name              0
# type1             0
# type2           384
# hp                0
# attack            0
# defense           0
# sp_attack         0
# sp_defense        0
# speed             0
# generation        0
# is_legendary      0
# dtype: int64

# %%
df_pokemon.type2.isna().sum()
# Out:
# np.int64(384)

# %%
df_pokemon[df_pokemon.isna().any(axis=1)]
# Out:
#            name     type1 type2  hp  attack  defense  sp_attack  sp_defense  \
# 3    Charmander      fire   NaN  39      52       43         60          50
# 4    Charmeleon      fire   NaN  58      64       58         80          65
# 6      Squirtle     water   NaN  44      48       65         50          64
# 7     Wartortle     water   NaN  59      63       80         65          80
# 8     Blastoise     water   NaN  79     103      120        135         115
# ..          ...       ...   ...  ..     ...      ...        ...         ...
# 781    Jangmo-o    dragon   NaN  45      55       65         45          45
# 788      Cosmog   psychic   NaN  43      29       31         29          31
# 789     Cosmoem   psychic   NaN  43      29      131         29         131
# 795   Xurkitree  electric   NaN  83      89       71        173          71
# 799    Necrozma   psychic   NaN  97     107      101        127          89
#
#      speed  generation  is_legendary
# ...

# %%
# Coluna Type2 possui 384 linhas nulas, não é dado faltante é característica.

# %%
# Preenchendo onde estiver null com 'none' (tratando os dados nulos)

df_pokemon = df_pokemon.fillna(value={'type2': 'none'})

# %%
df_pokemon.head(10)
# Out:
#          name  type1   type2  hp  attack  defense  sp_attack  sp_defense  \
# 0   Bulbasaur  grass  poison  45      49       49         65          65
# 1     Ivysaur  grass  poison  60      62       63         80          80
# 2    Venusaur  grass  poison  80     100      123        122         120
# 3  Charmander   fire    none  39      52       43         60          50
# 4  Charmeleon   fire    none  58      64       58         80          65
# 5   Charizard   fire  flying  78     104       78        159         115
# 6    Squirtle  water    none  44      48       65         50          64
# 7   Wartortle  water    none  59      63       80         65          80
# 8   Blastoise  water    none  79     103      120        135         115
# 9    Caterpie    bug    none  45      30       35         20          20
#
#    speed  generation  is_legendary
# 0     45           1             0
# 1     60           1             0
# 2     80           1             0
# ...

# %%
## Checando os tipos de dados
df_pokemon.dtypes
# Out:
# name              str
# type1             str
# type2             str
# hp              int64
# attack          int64
# defense         int64
# sp_attack       int64
# sp_defense      int64
# speed           int64
# generation      int64
# is_legendary    int64
# dtype: object

# %%
df_pokemon.to_csv('../data/pokemon_clean.csv', index=False)
